# %%
#Using Random Forest Regressor
#Calculating importance of the features of attacks as weights

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
import os
import time

start_time=time.time()

def create_folder(f_name):
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print("Couldn't make folder")

csv_files=os.listdir(".\\attacks")

main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]


obj=open("imp_features_attack.csv","w")
create_folder("feature_attack")

for i in csv_files:
    df=pd.read_csv("./attacks/"+i, usecols=main_labels)
    df=df.fillna(0)
    attack_class=[]
    for j in df["Label"]:   #Labelling attack as 0 and normal(benign) as 1
        if j== "BENIGN":
            attack_class.append(1)
        else:
            attack_class.append(0)
    df["Label"] = attack_class
    
    y=df["Label"].values
    del df["Label"]
    x=df.values

    x = np.float32(x)
    x[np.isnan(x)] = 0
    x[np.isinf(x)] = 0

    #computing importance of features with feature_importance_
    rfr=sk.ensemble.RandomForestRegressor(n_estimators=250, random_state=0)
    rfr.fit(x,y)
    imp=rfr.feature_importances_
    std = np.std([tree.feature_importances_ for tree in rfr.estimators_], axis=0)
    indices = np.argsort(imp)[::-1]
    refclasscol= list(df.columns.values)
    imp_bars= pd.DataFrame({'Features':refclasscol[0:20],'importance':imp[0:20]}) #top 20 features
    imp_bars= imp_bars.sort_values(by='importance', ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (8,5)
    imp_bars.plot.bar();

    #Plotting importance of features
    count=0
    feature=i[0:4]+"=["     #top 5 features
    for j in imp_bars.index:
        feature = feature+ "\""+ str(j) + "\","
        count+=1
        if count ==5:
            feature=feature[:-1] + "]"
            break
    print(i[0:4], "Importance List")
    print(i[0:4], "\n", imp_bars.head(20), "\n\n")
    print(feature)
    plt.title(i[0:4] + "Attack Features Importance")
    plt.ylabel("Importance")
    plt.savefig("./feature_attack/"+i[0:4]+".pdf", bbox_inches='tight', format='pdf')
    obj.write((feature))
    plt.tight_layout()
    plt.show()
    print("\n\n")

print("Time taken: ",time.time()-start_time)
obj.close()
# Out:
# Bot. Importance List
# Bot.
#                               importance
# Features
# Bwd Packet Length Mean         0.344846
# Flow Duration                  0.014568
# Flow IAT Min                   0.012092
# Flow IAT Max                   0.012022
# Flow IAT Std                   0.011307
# Flow IAT Mean                  0.005021
# Fwd IAT Total                  0.000710
# Flow Packets/s                 0.000635
# Flow Bytes/s                   0.000573
# Bwd Packet Length Max          0.000414
# Fwd Packet Length Mean         0.000344
# Fwd Packet Length Min          0.000190
# Total Length of Bwd Packets    0.000123
# Total Backward Packets         0.000100
# Total Length of Fwd Packets    0.000072
# Bwd Packet Length Std          0.000052
# Fwd Packet Length Max          0.000042
# Fwd Packet Length Std          0.000025
# Total Fwd Packets              0.000018
# Bwd Packet Length Min          0.000003
#
#
# Bot.=["Bwd Packet Length Mean","Flow Duration","Flow IAT Min","Flow IAT Max","Flow IAT Std"]
# DDoS Importance List
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.472687
# Total Backward Packets         0.094634
# Fwd IAT Total                  0.011787
# Flow Duration                  0.007587
# Total Length of Fwd Packets    0.007224
# Flow IAT Min                   0.005905
# Flow IAT Std                   0.005429
# Flow IAT Mean                  0.005143
# Flow IAT Max                   0.004490
# Flow Bytes/s                   0.002486
# Fwd Packet Length Max          0.002129
# Flow Packets/s                 0.001000
# Fwd Packet Length Std          0.000592
# Bwd Packet Length Max          0.000578
# Bwd Packet Length Min          0.000470
# Bwd Packet Length Mean         0.000211
# Fwd Packet Length Mean         0.000193
# Total Length of Bwd Packets    0.000108
# Total Fwd Packets              0.000038
# Fwd Packet Length Min          0.000019
#
#
# DDoS=["Bwd Packet Length Std","Total Backward Packets","Fwd IAT Total","Flow Duration","Total Length of Fwd Packets"]
# DoS  Importance List
# DoS
#                               importance
# Features
# Flow IAT Max                   0.311888
# Bwd Packet Length Std          0.216465
# Flow IAT Min                   0.062267
# Total Backward Packets         0.025664
# Fwd Packet Length Min          0.013743
# Flow IAT Mean                  0.007907
# Flow Duration                  0.001674
# Flow IAT Std                   0.001513
# Bwd Packet Length Mean         0.001048
# Fwd Packet Length Max          0.000898
# Flow Packets/s                 0.000890
# Flow Bytes/s                   0.000720
# Total Length of Fwd Packets    0.000421
# Fwd IAT Total                  0.000397
# Fwd Packet Length Mean         0.000369
# Total Length of Bwd Packets    0.000356
# Bwd Packet Length Max          0.000302
# Bwd Packet Length Min          0.000037
# Fwd Packet Length Std          0.000032
# Total Fwd Packets              0.000014
#
#
# DoS =["Flow IAT Max","Bwd Packet Length Std","Flow IAT Min","Total Backward Packets","Fwd Packet Length Min"]
# DoS  Importance List
# DoS
#                                 importance
# Features
# Bwd Packet Length Std        5.139563e-01
# Fwd Packet Length Std        7.424189e-02
# Fwd Packet Length Max        3.905860e-03
# Flow IAT Min                 1.796279e-03
# Flow Duration                1.601041e-03
# Total Backward Packets       3.827420e-04
# Total Length of Bwd Packets  2.257079e-04
# Fwd IAT Total                1.633682e-04
# Flow IAT Max                 1.562498e-04
# Bwd Packet Length Mean       1.495917e-04
# Flow IAT Std                 1.092654e-04
# Flow IAT Mean                7.933737e-05
# Flow Packets/s               6.616045e-05
# Flow Bytes/s                 2.161743e-05
# Bwd Packet Length Max        1.474061e-05
# Fwd Packet Length Mean       1.446235e-05
# Total Fwd Packets            9.071800e-06
# Bwd Packet Length Min        7.514751e-06
# Total Length of Fwd Packets  4.289146e-06
# Fwd Packet Length Min        2.618867e-07
#
#
# DoS =["Bwd Packet Length Std","Fwd Packet Length Std","Fwd Packet Length Max","Flow IAT Min","Flow Duration"]
# DoS  Importance List
# DoS
#                               importance
# Features
# Flow IAT Mean                  0.646918
# Fwd Packet Length Min          0.080955
# Fwd Packet Length Std          0.021115
# Bwd Packet Length Mean         0.020934
# Fwd Packet Length Mean         0.016622
# Total Length of Bwd Packets    0.014364
# Bwd Packet Length Std          0.011426
# Bwd Packet Length Max          0.005396
# Flow IAT Min                   0.002002
# Bwd Packet Length Min          0.000826
# Total Fwd Packets              0.000746
# Total Length of Fwd Packets    0.000611
# Flow Bytes/s                   0.000437
# Total Backward Packets         0.000419
# Flow Duration                  0.000351
# Flow IAT Max                   0.000238
# Fwd IAT Total                  0.000190
# Fwd Packet Length Max          0.000136
# Flow IAT Std                   0.000124
# Flow Packets/s                 0.000119
#
#
# DoS =["Flow IAT Mean","Fwd Packet Length Min","Fwd Packet Length Std","Bwd Packet Length Mean","Fwd Packet Length Mean"]
# DoS  Importance List
# DoS
#                               importance
# Features
# Flow IAT Mean                  0.472436
# Bwd Packet Length Mean         0.118264
# Total Fwd Packets              0.021369
# Fwd Packet Length Std          0.007695
# Flow Bytes/s                   0.002065
# Fwd Packet Length Min          0.002012
# Total Length of Bwd Packets    0.001478
# Flow IAT Max                   0.000893
# Fwd Packet Length Max          0.000837
# Flow IAT Min                   0.000819
# Bwd Packet Length Std          0.000555
# Flow Duration                  0.000513
# Bwd Packet Length Max          0.000445
# Flow IAT Std                   0.000440
# Total Length of Fwd Packets    0.000404
# Flow Packets/s                 0.000376
# Fwd Packet Length Mean         0.000357
# Total Backward Packets         0.000346
# Fwd IAT Total                  0.000205
# Bwd Packet Length Min          0.000009
#
#
# DoS =["Flow IAT Mean","Bwd Packet Length Mean","Total Fwd Packets","Fwd Packet Length Std","Flow Bytes/s"]
# FTP- Importance List
# FTP-
#                               importance
# Features
# Fwd Packet Length Max          0.108307
# Fwd Packet Length Std          0.025741
# Fwd Packet Length Mean         0.002138
# Bwd Packet Length Std          0.000540
# Total Length of Bwd Packets    0.000525
# Bwd Packet Length Mean         0.000405
# Flow IAT Min                   0.000251
# Flow Duration                  0.000195
# Bwd Packet Length Max          0.000159
# Total Fwd Packets              0.000139
# Total Length of Fwd Packets    0.000131
# Flow IAT Max                   0.000087
# Fwd IAT Total                  0.000086
# Flow Packets/s                 0.000085
# Flow IAT Mean                  0.000073
# Total Backward Packets         0.000061
# Fwd Packet Length Min          0.000022
# Flow IAT Std                   0.000018
# Bwd Packet Length Min          0.000011
# Flow Bytes/s                   0.000002
#
#
# FTP-=["Fwd Packet Length Max","Fwd Packet Length Std","Fwd Packet Length Mean","Bwd Packet Length Std","Total Length of Bwd Packets"]
# Hear Importance List
# Hear
#                               importance
# Features
# Bwd Packet Length Mean            0.052
# Total Length of Bwd Packets       0.048
# Bwd Packet Length Max             0.048
# Total Fwd Packets                 0.040
# Total Backward Packets            0.040
# Total Length of Fwd Packets       0.040
# Bwd Packet Length Std             0.036
# Flow IAT Min                      0.032
# Fwd Packet Length Max             0.032
# Flow Duration                     0.016
# Fwd IAT Total                     0.008
# Fwd Packet Length Mean            0.000
# Bwd Packet Length Min             0.000
# Fwd Packet Length Std             0.000
# Fwd Packet Length Min             0.000
# Flow Bytes/s                      0.000
# Flow IAT Mean                     0.000
# Flow Packets/s                    0.000
# Flow IAT Max                      0.000
# Flow IAT Std                      0.000
#
#
# Hear=["Bwd Packet Length Mean","Total Length of Bwd Packets","Bwd Packet Length Max","Total Fwd Packets","Total Backward Packets"]
# Infi Importance List
# Infi
#                               importance
# Features
# Flow Duration                  0.169169
# Fwd Packet Length Mean         0.096589
# Total Length of Fwd Packets    0.059984
# Fwd IAT Total                  0.021702
# Total Fwd Packets              0.019819
# Bwd Packet Length Mean         0.019439
# Flow IAT Mean                  0.017243
# Bwd Packet Length Std          0.015166
# Total Backward Packets         0.015061
# Flow IAT Max                   0.012993
# Flow IAT Min                   0.005583
# Bwd Packet Length Max          0.004812
# Fwd Packet Length Std          0.003935
# Fwd Packet Length Max          0.003802
# Flow Bytes/s                   0.003754
# Flow IAT Std                   0.002874
# Fwd Packet Length Min          0.001412
# Flow Packets/s                 0.001017
# Bwd Packet Length Min          0.000422
# Total Length of Bwd Packets    0.000237
#
#
# Infi=["Flow Duration","Fwd Packet Length Mean","Total Length of Fwd Packets","Fwd IAT Total","Total Fwd Packets"]
# Port Importance List
# Port
#                               importance
# Features
# Flow Bytes/s                   0.313755
# Total Length of Fwd Packets    0.304177
# Flow IAT Max                   0.000562
# Flow Duration                  0.000311
# Flow IAT Mean                  0.000248
# Fwd Packet Length Max          0.000159
# Total Length of Bwd Packets    0.000066
# Bwd Packet Length Min          0.000058
# Bwd Packet Length Mean         0.000043
# Flow Packets/s                 0.000042
# Flow IAT Min                   0.000036
# Fwd IAT Total                  0.000028
# Bwd Packet Length Max          0.000028
# Bwd Packet Length Std          0.000017
# Flow IAT Std                   0.000016
# Total Fwd Packets              0.000014
# Fwd Packet Length Std          0.000012
# Total Backward Packets         0.000009
# Fwd Packet Length Min          0.000003
# Fwd Packet Length Mean         0.000002
#
#
# Port=["Flow Bytes/s","Total Length of Fwd Packets","Flow IAT Max","Flow Duration","Flow IAT Mean"]
# SSH- Importance List
# SSH-
#                               importance
# Features
# Fwd Packet Length Max          0.000937
# Flow IAT Max                   0.000626
# Flow IAT Mean                  0.000494
# Flow Duration                  0.000492
# Total Length of Fwd Packets    0.000413
# Flow Packets/s                 0.000379
# Fwd Packet Length Min          0.000344
# Fwd IAT Total                  0.000317
# Flow Bytes/s                   0.000290
# Flow IAT Std                   0.000236
# Total Backward Packets         0.000197
# Fwd Packet Length Mean         0.000185
# Bwd Packet Length Min          0.000143
# Fwd Packet Length Std          0.000132
# Flow IAT Min                   0.000111
# Total Fwd Packets              0.000038
# Total Length of Bwd Packets    0.000036
# Bwd Packet Length Mean         0.000031
# Bwd Packet Length Max          0.000025
# Bwd Packet Length Std          0.000007
#
#
# SSH-=["Fwd Packet Length Max","Flow IAT Max","Flow IAT Mean","Flow Duration","Total Length of Fwd Packets"]
# web_ Importance List
# web_
#                               importance
# Features
# Total Length of Fwd Packets    0.015712
# Bwd Packet Length Std          0.005522
# Flow Bytes/s                   0.001979
# Flow IAT Min                   0.001329
# Fwd Packet Length Std          0.001125
# Bwd Packet Length Max          0.001117
# Fwd Packet Length Mean         0.000854
# Flow IAT Max                   0.000685
# Flow Packets/s                 0.000473
# Flow IAT Mean                  0.000433
# Fwd Packet Length Max          0.000370
# Flow Duration                  0.000358
# Bwd Packet Length Mean         0.000247
# Fwd IAT Total                  0.000165
# Total Fwd Packets              0.000150
# Total Length of Bwd Packets    0.000117
# Total Backward Packets         0.000092
# Flow IAT Std                   0.000074
# Fwd Packet Length Min          0.000045
# Bwd Packet Length Min          0.000006
#
#
# web_=["Total Length of Fwd Packets","Bwd Packet Length Std","Flow Bytes/s","Flow IAT Min","Fwd Packet Length Std"]
# Time taken:  11161.530142784119
